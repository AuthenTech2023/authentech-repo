# %% [markdown]
# # Data Visualization

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sb
# %matplotlib inline

# %% [markdown]
# ## Raw Data

# %%
raw_data = []
for user in range(1,16):
    raw_data.append(pd.read_csv('../raw-data/vol' + str(user) + '.csv'))

# %%
raw_data[0]
# Out:
#         Timestamp    X     Y BTN_TOUCH  TOUCH_MAJOR  TOUCH_MINOR  TRACKING_ID  \
# 0        0.000000  350  1404      DOWN           11         -420         2526
# 1        0.032676  348  1406      HELD           11         -420         2526
# 2        0.042109  347  1408      HELD           11         -420         2526
# 3        0.049881  344  1411      HELD           11         -420         2526
# 4        0.058581  340  1416      HELD           11         -420         2526
# ...           ...  ...   ...       ...          ...          ...          ...
# 59560  898.745893  710  1825      HELD         -420         -420         3509
# 59561  898.779799  677  1824      HELD            9            3   4294967295
# 59562  898.846378  677  1823      HELD            9            3   4294967295
# 59563  898.871367  677   303      HELD            9            3   4294967295
# 59564  898.904673  677   304      HELD            9            3   4294967295
#
#        PRESSURE  FINGER
# ...

# %%
raw_data[3]
# Out:
#         Timestamp    X     Y BTN_TOUCH  TOUCH_MAJOR  TOUCH_MINOR  TRACKING_ID  \
# 0        0.000000   49    19      DOWN         -420         -420         5181
# 1        0.032378   49    19      HELD         -420         -420         5181
# 2        0.041244   49    19      HELD         -420         -420         5181
# 3        0.049351   49    19      HELD         -420         -420         5181
# 4        0.058163   49    19      HELD         -420         -420         5181
# ...           ...  ...   ...       ...          ...          ...          ...
# 53353  896.514188  257  1468      HELD            9            2   4294967295
# 53354  896.531178  266  1471        UP           10            2   4294967295
# 53355  897.330117  510  1317      DOWN           14            3         6526
# 53356  897.363985  266  1471      HELD           13            2   4294967295
# 53357  897.396995  510  1317        UP           14            3   4294967295
#
#        PRESSURE  FINGER
# ...

# %%
sb.pairplot(raw_data[0])

# %%
sb.pairplot(raw_data[1])

# %%
sb.pairplot(raw_data[3])

# %% [markdown]
# ## Processed Data

# %%
processed_user_1 = pd.read_csv('../processed-feature-data/user1.csv')

# %%
processed_user_1
# Out:
#        Unnamed: 0  Timestamp         X         Y  TOUCH_MAJOR  TOUCH_MINOR  \
# 0               0  -2.077030 -1.066565  1.321646     0.200378    -1.878093
# 1               1  -2.076996 -1.097111  1.331405     0.200378    -1.878093
# 2               2  -2.076963 -1.135293  1.339212     0.200378    -1.878093
# 3               3  -2.076930 -1.173476  1.347019     0.200378    -1.878093
# 4               4  -2.076897 -1.219295  1.354826     0.200378    -1.878093
# ...           ...        ...       ...       ...          ...          ...
# 59234       59234   1.446262  1.713115  2.141393    -5.395770    -1.878093
# 59235       59235   1.446719  1.713115  2.139441    -5.395770    -1.878093
# 59236       59236   1.446883  1.728387  2.139441    -5.395770    -1.878093
# 59237       59237   1.447047  1.728387  2.131634    -5.395770    -1.878093
# 59238       59238   1.447371  1.728387  2.129682    -5.395770    -1.878093
#
# ...

# %% [markdown]
# # Split Data

# %% [markdown]
# ### Training Data

# %%
x_train = pd.read_csv('../processed-feature-data/training-data/X_training_data.csv')
y_train = pd.read_csv('../processed-feature-data/training-data/y_training_data.csv')
x_train_withuser = pd.read_csv('../processed-feature-data/training-data/X_training_dataVISUALIZATION.csv')

# %%
x_train
# Out:
#         Timestamp         X         Y  TOUCH_MAJOR  TOUCH_MINOR  TRACKING_ID  \
# 0        1.439571 -0.623649  0.937145     0.174410     0.533401     1.508205
# 1        0.638291 -0.348736 -0.840925     0.187394     0.533401     1.508205
# 2       -1.828330  0.162909  0.784907     0.187394     0.533401     1.508205
# 3        1.056103 -0.318190 -0.343222     0.200378     0.533401    -0.663040
# 4        0.559838 -0.188370 -1.129789     0.187394     0.533401    -0.663040
# ...           ...       ...       ...          ...          ...          ...
# 532429  -0.268482 -0.639854  0.978884     0.231223     0.484658     1.175282
# 532430  -1.126508  1.887418  0.447761     0.209554     0.484658     1.175282
# 532431  -0.811074 -0.039169 -1.183228     0.231223     0.484658    -0.850860
# 532432   0.341027  0.766628  0.866021     0.220388     0.484658    -0.850860
# 532433   0.358297 -0.830315 -1.032743     0.231223     0.484658     1.175282
#
# ...

# %%
sb.stripplot(x="User", y='X' , data=x_train_withuser ,jitter=True)
# Out:
# <Axes: xlabel='User', ylabel='X'>

# %%
sb.stripplot(x="User", y='Y' , data=x_train_withuser ,jitter=True)
# Out:
# <Axes: xlabel='User', ylabel='Y'>

# %%
sb.stripplot(x="User", y='TOUCH_MAJOR' , data=x_train_withuser ,jitter=True)
# Out:
# <Axes: xlabel='User', ylabel='TOUCH_MAJOR'>

# %%
sb.stripplot(x="User", y='TOUCH_MINOR' , data=x_train_withuser ,jitter=True)
# Out:
# <Axes: xlabel='User', ylabel='TOUCH_MINOR'>

# %%
sb.stripplot(x="User", y='TRACKING_ID' , data=x_train_withuser ,jitter=True)
# Out:
# <Axes: xlabel='User', ylabel='TRACKING_ID'>

# %%
sb.stripplot(x="User", y='PRESSURE' , data=x_train_withuser ,jitter=True)
# Out:
# <Axes: xlabel='User', ylabel='PRESSURE'>

# %%
sb.stripplot(x="User", y='FINGER' , data=x_train_withuser ,jitter=True)
# Out:
# <Axes: xlabel='User', ylabel='FINGER'>

# %%
sb.stripplot(x="User", y='BTN_TOUCH_HELD' , data=x_train_withuser ,jitter=True)
# Out:
# <Axes: xlabel='User', ylabel='BTN_TOUCH_HELD'>

# %%
sb.stripplot(x="User", y='BTN_TOUCH_UP' , data=x_train_withuser ,jitter=True)
# Out:
# <Axes: xlabel='User', ylabel='BTN_TOUCH_UP'>

# %%
sb.stripplot(x="User", y='X_Speed' , data=x_train_withuser ,jitter=True)
# Out:
# <Axes: xlabel='User', ylabel='X_Speed'>

# %%
sb.stripplot(x="User", y='X_Acceleration' , data=x_train_withuser ,jitter=True)
# Out:
# <Axes: xlabel='User', ylabel='X_Acceleration'>

# %%
sb.stripplot(x="User", y='Y_Speed' , data=x_train_withuser ,jitter=True)
# Out:
# <Axes: xlabel='User', ylabel='Y_Speed'>

# %%
sb.stripplot(x="User", y='Y_Acceleration' , data=x_train_withuser ,jitter=True)
# Out:
# <Axes: xlabel='User', ylabel='Y_Acceleration'>

# %%
sb.stripplot(x="User", y='Speed' , data=x_train_withuser ,jitter=True)
# Out:
# <Axes: xlabel='User', ylabel='Speed'>

# %%
sb.stripplot(x="User", y='Acceleration' , data=x_train_withuser ,jitter=True)
# Out:
# <Axes: xlabel='User', ylabel='Acceleration'>

# %%
sb.stripplot(x="User", y='Jerk' , data=x_train_withuser ,jitter=True)
# Out:
# <Axes: xlabel='User', ylabel='Jerk'>

# %%
sb.stripplot(x="User", y='Ang_V' , data=x_train_withuser ,jitter=True)
# Out:
# <Axes: xlabel='User', ylabel='Ang_V'>

# %%
sb.stripplot(x="User", y='Path_Tangent' , data=x_train_withuser ,jitter=True)
# Out:
# <Axes: xlabel='User', ylabel='Path_Tangent'>

# %%
y_train

# %% [markdown]
# ### Testing Data

# %%
x_test_user_1 = pd.read_csv('../processed-feature-data/testing-data/X_testing_data_user1.csv')
y_test_user_1 = pd.read_csv('../processed-feature-data/testing-data/y_testing_data_user1.csv')

# %%
x_test_user_1

# %%
y_test_user_1
