# %%
import pandas as pd
import seaborn as sb
import numpy as np
import sklearn as sk
import matplotlib as plt
# %matplotlib inline

# %%
df = pd.read_csv('Event Recordings/vol1.csv', )

# %%
df.head()
# Out:
#    Timestamp    X     Y BTN_TOUCH  TOUCH_MAJOR  TOUCH_MINOR  TRACKING_ID  \
# 0   0.000000  350  1404      DOWN           11         -420         2526
# 1   0.032676  348  1406      HELD           11         -420         2526
# 2   0.042109  347  1408      HELD           11         -420         2526
# 3   0.049881  344  1411      HELD           11         -420         2526
# 4   0.058581  340  1416      HELD           11         -420         2526
#
#    PRESSURE  FINGER
# 0        38       0
# 1        38       0
# 2        38       0
# 3        38       0
# 4        38       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59565 entries, 0 to 59564
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Timestamp    59565 non-null  float64
#  1   X            59565 non-null  int64
#  2   Y            59565 non-null  int64
#  3   BTN_TOUCH    59435 non-null  object
#  4   TOUCH_MAJOR  59565 non-null  int64
#  5   TOUCH_MINOR  59565 non-null  int64
#  6   TRACKING_ID  59565 non-null  int64
#  7   PRESSURE     59565 non-null  int64
#  8   FINGER       59565 non-null  int64
# dtypes: float64(1), int64(7), object(1)
# memory usage: 4.1+ MB

# %%
df.describe()
# Out:
#           Timestamp             X             Y   TOUCH_MAJOR   TOUCH_MINOR  \
# count  59565.000000  59565.000000  59565.000000  59565.000000  59565.000000
# mean     529.775197    478.859498    727.729892     -4.673097    -92.366843
# std      254.573110    146.215525    517.848277     77.638527    176.611162
# min        0.000000   -420.000000   -420.000000   -420.000000   -420.000000
# 25%      314.205932    395.000000    292.000000      9.000000      2.000000
# 50%      581.293803    478.000000    407.000000     10.000000      3.000000
# 75%      755.046008    568.000000   1205.000000     10.000000      3.000000
# max      898.904673   1177.000000   1857.000000     12.000000      3.000000
#
#         TRACKING_ID      PRESSURE        FINGER
# count  5.956500e+04  59565.000000  59565.000000
# mean   1.304536e+09     21.560262      0.208344
# std    1.975141e+09     27.269898      0.406127
# min   -4.200000e+02   -420.000000      0.000000
# ...

# %%
sb.pairplot(data=df,hue='BTN_TOUCH')
