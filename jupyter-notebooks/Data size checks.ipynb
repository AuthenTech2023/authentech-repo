# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import sklearn as sk
from sklearn.model_selection import train_test_split

# %%
xtrain = pd.read_csv('../processed-feature-data/training-data/X_training_data.csv')
ytrain = pd.read_csv('../processed-feature-data/training-data/y_training_data.csv')
xtest = pd.read_csv('../processed-feature-data/testing-data/X_testing_data_user1.csv')
ytest = pd.read_csv('../processed-feature-data/testing-data/y_testing_data_user1.csv')

# %% [markdown]
# # X Train

# %%
xtrain
# Out:
#         Timestamp         X         Y  TOUCH_MAJOR  TOUCH_MINOR  TRACKING_ID  \
# 0        1.315676 -0.026441  1.479824     0.189000    -1.855333    -0.660505
# 1        0.734405 -0.655651  1.699972     0.189000     0.539926    -0.660505
# 2       -1.616878 -0.983935 -1.171601     0.189000     0.539926    -0.660505
# 3       -2.059747  0.185575 -0.874209     0.189000    -1.855333     1.513993
# 4        0.710989 -0.238457 -1.069252     0.189000    -1.855333    -0.660505
# ...           ...       ...       ...          ...          ...          ...
# 538281  -0.268986 -0.601957  0.977553     0.235384     0.487705     1.177498
# 538282  -1.127770  1.824041  0.450785     0.214077     0.487705     1.177498
# 538283  -0.812057 -0.025343 -1.166829     0.235384     0.487705    -0.849258
# 538284   0.341062  0.748164  0.865614     0.224730     0.487705    -0.849258
# 538285   0.358347 -0.784786 -1.017579     0.235384     0.487705     1.177498
#
# ...

# %% [markdown]
# # y Train

# %%
ytrain
# Out:
#            0
# 0        1.0
# 1        1.0
# 2        1.0
# 3        1.0
# 4        1.0
# ...      ...
# 538281  15.0
# 538282  15.0
# 538283  15.0
# 538284  15.0
# 538285  15.0
#
# [538286 rows x 1 columns]

# %%
ytrain.values.ravel()
# Out:
# array([ 1.,  1.,  1., ..., 15., 15., 15.])

# %% [markdown]
# # X Test

# %%
xtest
# Out:
#        Timestamp         X         Y  TOUCH_MAJOR  TOUCH_MINOR  TRACKING_ID  \
# 0      -1.604677  0.472824 -0.787309      0.18900     0.539926    -0.660505
# 1      -0.667824 -0.477831 -0.625095      0.17612     0.539926    -0.660505
# 2       0.689239 -0.559902  1.514585      0.17612     0.539926    -0.660505
# 3      -0.958949  0.014594 -1.015181      0.18900     0.539926    -0.660505
# 4       1.106832 -1.018131  1.468238      0.20188    -1.855333    -0.660505
# ...          ...       ...       ...          ...          ...          ...
# 17864  -0.317176 -0.710365 -0.831725      0.17612     0.539926    -0.660505
# 17865   1.251346 -0.272654  1.041460      0.18900    -1.855333    -0.660505
# 17866   0.161637  0.315521 -0.959178      0.18900     0.539926     1.513993
# 17867  -0.935760 -0.293171 -0.854898      0.17612     0.539926    -0.660505
# 17868  -1.513107  0.144540 -0.756411      0.18900     0.534264    -0.660505
#
# ...

# %% [markdown]
# # y Test

# %%
ytest
# Out:
#        User
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ...     ...
# 17864     1
# 17865     1
# 17866     1
# 17867     1
# 17868     1
#
# [17869 rows x 1 columns]

# %%
user1 = pd.read_csv('../processed-feature-data/user1.csv')
user1
# Out:
#        Unnamed: 0  Timestamp         X         Y  TOUCH_MAJOR  TOUCH_MINOR  \
# 0               0  -2.081135 -0.922382  1.319542      0.20188    -1.855333
# 1               1  -2.081100 -0.949739  1.329197      0.20188    -1.855333
# 2               2  -2.081068 -0.983935  1.336922      0.20188    -1.855333
# 3               3  -2.081035 -1.018131  1.344646      0.20188    -1.855333
# 4               4  -2.081002 -1.059166  1.352371      0.20188    -1.855333
# ...           ...        ...       ...       ...          ...          ...
# 59557       59557   1.448288  1.567102  2.130611     -5.34940    -1.855333
# 59558       59558   1.448746  1.567102  2.128680     -5.34940    -1.855333
# 59559       59559   1.448910  1.580781  2.128680     -5.34940    -1.855333
# 59560       59560   1.449075  1.580781  2.120956     -5.34940    -1.855333
# 59561       59561   1.449399  1.580781  2.119025     -5.34940    -1.855333
#
# ...
