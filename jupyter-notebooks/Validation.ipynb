# %% [markdown]
# ## Validation Script
#
# #### We need to first both train and test with a single user to make sure our scripts work

# %% [markdown]
# ### Clean the data

# %%
# imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# data cleaning function
from DataCleaningFunction import clean_data

# %matplotlib inline

# %%
# For this instance, we are only using volunteer 1's data
clean_data('Event Recordings/vol1.csv')
# Out:
#         Timestamp    X     Y  TOUCH_MAJOR  TOUCH_MINOR  TRACKING_ID  PRESSURE  \
# 3        0.049881  344  1411           11         -420         2526        38
# 4        0.058581  340  1416           11         -420         2526        38
# 5        0.066807  335  1420           11         -420         2526        38
# 6        0.075273  330  1424           11         -420         2526        38
# 7        0.083722  324  1428           11         -420         2526        38
# ...           ...  ...   ...          ...          ...          ...       ...
# 59545  898.462922  675   303            9            3   4294967295        31
# 59552  898.621411  677  1829            9            3   4294967295        31
# 59556  898.663272  677   303            9            3   4294967295        31
# 59563  898.871367  677   303            9            3   4294967295        31
# 59564  898.904673  677   304            9            3   4294967295        31
#
# ...
