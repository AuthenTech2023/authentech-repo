# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import sklearn as sk
from sklearn.model_selection import train_test_split

# %%
X_training_data = pd.DataFrame()  # df with all users X training data
y_training_data = pd.DataFrame()  # df with all users y training data
X_testing_data = []  # array of X testing data for each user where index+1 is user id
y_testing_data = []  # array of y testing data for each user where index+1 is user id

# %%
df = pd.read_csv('../processed-feature-data/user1.csv')
df.drop(columns=df.columns[0], axis=1, inplace=True)

# %%
df
# Out:
#        Timestamp         X         Y  TOUCH_MAJOR  TOUCH_MINOR  TRACKING_ID  \
# 0      -2.081135 -0.922382  1.319542      0.20188    -1.855333    -0.660506
# 1      -2.081100 -0.949739  1.329197      0.20188    -1.855333    -0.660506
# 2      -2.081068 -0.983935  1.336922      0.20188    -1.855333    -0.660506
# 3      -2.081035 -1.018131  1.344646      0.20188    -1.855333    -0.660506
# 4      -2.081002 -1.059166  1.352371      0.20188    -1.855333    -0.660506
# ...          ...       ...       ...          ...          ...          ...
# 59557   1.448288  1.567102  2.130611     -5.34940    -1.855333    -0.660505
# 59558   1.448746  1.567102  2.128680     -5.34940    -1.855333    -0.660505
# 59559   1.448910  1.580781  2.128680     -5.34940    -1.855333    -0.660505
# 59560   1.449075  1.580781  2.120956     -5.34940    -1.855333    -0.660505
# 59561   1.449399  1.580781  2.119025     -5.34940    -1.855333    -0.660505
#
#        PRESSURE    FINGER  BTN_TOUCH_HELD  BTN_TOUCH_UP   X_Speed  \
# 0      0.602879 -0.513022        0.149258     -0.099509 -0.089431
# 1      0.602879 -0.513022        0.149258     -0.099509 -0.105890
# 2      0.602879 -0.513022        0.149258     -0.099509 -0.138923
# 3      0.602879 -0.513022        0.149258     -0.099509 -0.135078
# 4      0.602879 -0.513022        0.149258     -0.099509 -0.161749
# ...         ...       ...             ...           ...       ...
# 59557  0.052826  1.949235        0.149258     -0.099509  0.221545
# 59558  0.052826  1.949235        0.149258     -0.099509 -0.003312
# 59559  0.052826  1.949235        0.149258     -0.099509  0.007372
# 59560  0.052826  1.949235        0.149258     -0.099509 -0.003312
# 59561  0.052826  1.949235        0.149258     -0.099509 -0.003312
#
#        X_Acceleration   Y_Speed  Y_Acceleration     Speed  Acceleration  \
# 0           -0.041425  0.019004        0.007027 -0.227304     -0.000227
# 1           -0.009255  0.025880        0.006897 -0.220262     -0.005171
# 2           -0.020372  0.022657        0.000854 -0.218690     -0.009785
# 3            0.003025  0.022155        0.002554 -0.219508     -0.011930
# 4           -0.015876  0.022190        0.002878 -0.215909     -0.008032
# ...               ...       ...             ...       ...           ...
# 59557        0.004366  0.066645        0.003854 -0.174521     -0.009489
# 59558       -0.009436  0.004627        0.000141 -0.247210     -0.015855
# 59559        0.001987  0.004939        0.002895 -0.245754     -0.010949
# 59560       -0.000688  0.001457        0.002432 -0.243988     -0.010895
# 59561        0.000648  0.004498        0.003045 -0.247079     -0.011489
#
#            Jerk     Ang_V  Path_Tangent  User
# 0     -0.004962  0.239439      1.514632     1
# 1     -0.011820 -0.057225      1.442160     1
# 2     -0.011784  0.159984      1.587105     1
# 3     -0.010293  0.012500      1.587105     1
# 4     -0.006826  0.068776      1.643912     1
# ...         ...       ...           ...   ...
# 59557 -0.009017  0.030407      0.648659     1
# 59558 -0.009328 -0.109826     -1.057260     1
# 59559 -0.008494  0.218687     -0.028503     1
# 59560 -0.009057 -0.193200     -1.057260     1
# 59561 -0.009099  0.012500     -1.057260     1
#
# [59562 rows x 20 columns]

# %%
X = df
y = df['User']
X_train, X_test, y_train, y_test = train_test_split(df ,df['User'], test_size=0.3, random_state=101)
X_training_data = pd.concat([X_training_data, X_train])
y_training_data = pd.concat([y_training_data, y_train])
X_testing_data.append(X_test)
y_testing_data.append(y_test)

# %%
X_testing_data
# Out:
# [       Timestamp         X         Y  TOUCH_MAJOR  TOUCH_MINOR  TRACKING_ID  \
#  3814   -1.604677  0.472824 -0.787309      0.18900     0.539926    -0.660505
#  15296  -0.667824 -0.477831 -0.625095      0.17612     0.539926    -0.660505
#  32374   0.689239 -0.559902  1.514585      0.17612     0.539926    -0.660505
#  11298  -0.958949  0.014594 -1.015181      0.18900     0.539926    -0.660505
#  57309   1.106832 -1.018131  1.468238      0.20188    -1.855333    -0.660505
#  ...          ...       ...       ...          ...          ...          ...
#  19008  -0.317176 -0.710365 -0.831725      0.17612     0.539926    -0.660505
#  58556   1.251346 -0.272654  1.041460      0.18900    -1.855333    -0.660505
#  24217   0.161637  0.315521 -0.959178      0.18900     0.539926     1.513993
#  11536  -0.935760 -0.293171 -0.854898      0.17612     0.539926    -0.660505
#  4733   -1.513107  0.144540 -0.756411      0.18900     0.534264    -0.660505
#
#         PRESSURE    FINGER  BTN_TOUCH_HELD  BTN_TOUCH_UP   X_Speed  \
#  3814   0.199507 -0.513022        0.149258     -0.099509  0.022483
#  15296  0.016156 -0.513022        0.149258     -0.099509 -5.816281
#  32374 -0.057185 -0.513022        0.149258     -0.099509 -0.003312
#  11298  0.052826 -0.513022        0.149258     -0.099509  0.025723
#  57309  0.419528  1.949235        0.149258     -0.099509 -0.003312
#  ...         ...       ...             ...           ...       ...
#  19008 -0.167195 -0.513022        0.149258     -0.099509 -0.145945
#  58556 -0.020515  1.949235        0.149258     -0.099509  0.082300
#  24217  0.126166 -0.513022        0.149258     -0.099509 -0.003312
#  11536 -0.130525 -0.513022        0.149258     -0.099509  0.097039
#  4733   0.016156 -0.513022        0.149258     -0.099509  0.051344
#
#         X_Acceleration   Y_Speed  Y_Acceleration     Speed  Acceleration  \
#  3814         0.033128  0.009152        0.002657 -0.241470     -0.011630
#  15296       -4.023709 -0.033616       -0.023207  0.718518      0.941952
#  32374        0.020893  0.004939       -0.055881 -0.247528     -0.098499
#  11298       -0.016289 -0.004546       -0.000524 -0.236747     -0.010457
#  57309       -0.003596  0.007144        0.002863 -0.245285     -0.011617
#  ...               ...       ...             ...       ...           ...
#  19008       -0.045609  0.000280        0.002428 -0.223374     -0.000445
#  58556       -0.006809 -0.004383       -0.000655 -0.230442     -0.010708
#  24217       -0.007692  0.007137        0.002205 -0.245293     -0.012995
#  11536        0.010488 -3.150094       -3.825725  2.960226     -0.310445
#  4733         0.052505  0.009402        0.008333 -0.237381     -0.007565
#
#             Jerk     Ang_V  Path_Tangent  User
#  3814  -0.009721 -0.983085      0.485875     1
#  15296  1.135597 -2.235765     -2.059435     1
#  32374 -0.035934 -0.514735     -0.028503     1
#  11298 -0.007148 -0.446578     -0.753605     1
#  57309 -0.009060  0.273117      1.000254     1
#  ...         ...       ...           ...   ...
#  19008  0.001280 -0.074662     -1.956737     1
#  58556 -0.005808 -0.228021     -0.413602     1
#  24217 -0.011188  0.272253      1.000254     1
#  11536 -0.320489 -1.918433     -1.053858     1
#  4733  -0.006876  1.905915      0.275152     1
#
#  [17869 rows x 20 columns]]

# %%
X
# Out:
#        Timestamp         X         Y  TOUCH_MAJOR  TOUCH_MINOR  TRACKING_ID  \
# 0      -2.081135 -0.922382  1.319542      0.20188    -1.855333    -0.660506
# 1      -2.081100 -0.949739  1.329197      0.20188    -1.855333    -0.660506
# 2      -2.081068 -0.983935  1.336922      0.20188    -1.855333    -0.660506
# 3      -2.081035 -1.018131  1.344646      0.20188    -1.855333    -0.660506
# 4      -2.081002 -1.059166  1.352371      0.20188    -1.855333    -0.660506
# ...          ...       ...       ...          ...          ...          ...
# 59557   1.448288  1.567102  2.130611     -5.34940    -1.855333    -0.660505
# 59558   1.448746  1.567102  2.128680     -5.34940    -1.855333    -0.660505
# 59559   1.448910  1.580781  2.128680     -5.34940    -1.855333    -0.660505
# 59560   1.449075  1.580781  2.120956     -5.34940    -1.855333    -0.660505
# 59561   1.449399  1.580781  2.119025     -5.34940    -1.855333    -0.660505
#
#        PRESSURE    FINGER  BTN_TOUCH_HELD  BTN_TOUCH_UP   X_Speed  \
# 0      0.602879 -0.513022        0.149258     -0.099509 -0.089431
# 1      0.602879 -0.513022        0.149258     -0.099509 -0.105890
# 2      0.602879 -0.513022        0.149258     -0.099509 -0.138923
# 3      0.602879 -0.513022        0.149258     -0.099509 -0.135078
# 4      0.602879 -0.513022        0.149258     -0.099509 -0.161749
# ...         ...       ...             ...           ...       ...
# 59557  0.052826  1.949235        0.149258     -0.099509  0.221545
# 59558  0.052826  1.949235        0.149258     -0.099509 -0.003312
# 59559  0.052826  1.949235        0.149258     -0.099509  0.007372
# 59560  0.052826  1.949235        0.149258     -0.099509 -0.003312
# 59561  0.052826  1.949235        0.149258     -0.099509 -0.003312
#
#        X_Acceleration   Y_Speed  Y_Acceleration     Speed  Acceleration  \
# 0           -0.041425  0.019004        0.007027 -0.227304     -0.000227
# 1           -0.009255  0.025880        0.006897 -0.220262     -0.005171
# 2           -0.020372  0.022657        0.000854 -0.218690     -0.009785
# 3            0.003025  0.022155        0.002554 -0.219508     -0.011930
# 4           -0.015876  0.022190        0.002878 -0.215909     -0.008032
# ...               ...       ...             ...       ...           ...
# 59557        0.004366  0.066645        0.003854 -0.174521     -0.009489
# 59558       -0.009436  0.004627        0.000141 -0.247210     -0.015855
# 59559        0.001987  0.004939        0.002895 -0.245754     -0.010949
# 59560       -0.000688  0.001457        0.002432 -0.243988     -0.010895
# 59561        0.000648  0.004498        0.003045 -0.247079     -0.011489
#
#            Jerk     Ang_V  Path_Tangent  User
# 0     -0.004962  0.239439      1.514632     1
# 1     -0.011820 -0.057225      1.442160     1
# 2     -0.011784  0.159984      1.587105     1
# 3     -0.010293  0.012500      1.587105     1
# 4     -0.006826  0.068776      1.643912     1
# ...         ...       ...           ...   ...
# 59557 -0.009017  0.030407      0.648659     1
# 59558 -0.009328 -0.109826     -1.057260     1
# 59559 -0.008494  0.218687     -0.028503     1
# 59560 -0.009057 -0.193200     -1.057260     1
# 59561 -0.009099  0.012500     -1.057260     1
#
# [59562 rows x 20 columns]
